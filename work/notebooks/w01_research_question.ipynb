# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#setup
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

print("Working dir:", os.getcwd())
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
#Lane 3. I am choosing Lane 3 because it helps group pages by similar characteristics and identifies what action should be taken for these pages.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
#An SEO Engineer acts on this. Instead of reviewing each page individually, they use the archetype groupings to quickly decide which action fits each group — for example, protecting high performers, rewriting stale-but-visible pages, or pruning pages with no demand.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Number 1: clicks_90d spread
print("clicks_90d:")
print("  min:", df["clicks_90d"].min())
print("  max:", df["clicks_90d"].max())
print("  mean:", round(df["clicks_90d"].mean(), 2))

print()

# Number 2: users_90d spread
print("users_90d:")
print("  min:", df["users_90d"].min())
print("  max:", df["users_90d"].max())
print("  mean:", round(df["users_90d"].mean(), 2))

#clicks_90d ranges from 0 to 4,178, with a mean of only 16.1 — far closer to the minimum than the maximum. This suggests a small number of pages dominate traffic while most pages receive very little, hinting at distinct performance tiers rather than one uniform performance for all pages
#users_90d ranges from 1 to 4,913, with a mean of only 35.9, and just like clicks_90d, the minimum is way closer to the mean than the maximum which shows most pages are low-performing while only a small amount performs well
# Out:
# clicks_90d:
#   min: 0
#   max: 4178
#   mean: 16.1
#
# users_90d:
#   min: 1
#   max: 4913
#   mean: 35.94

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
#What I can say: the clustering shows groups of pages that behave similarly based on things like traffic, ranking position, and how long since they were updated. If a pattern shows up, I can say it looks like there's a real difference between groups of pages, not just random noise.
#What I can't say: I can't say these groups are the "true" types of pages — a different number of clusters or different features could group things differently. I also can't say being in a cluster causes a page to perform poorly, only that certain traits tend to show up together. And since the dataset doesn't have any actual article text, this isn't semantic clustering — I'm only grouping pages by their numbers, not what they're actually about. Finally, none of this tells me anything about how Google's algorithm actually works, only what's observable in this data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
